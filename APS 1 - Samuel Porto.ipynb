# %% [markdown]
# Samuel Naassom do Nascimento Porto - 2°Eng. A

# %% [markdown]
# Segue abaixo o banco de dados com as informações que pretendo analisar para responder minha pergunta relacionada ao IDH:

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt

data = pd.read_excel('Base_limpa.xlsx')
data.head(20)
# Out:
#                        geo  2000_IDH  2000_média_uso_contraceptivo_mulheres  \
# 0              Afghanistan     0.340                                    5.3
# 1                  Albania     0.662                                   57.5
# 2                  Algeria     0.644                                   64.0
# 3                   Angola     0.391                                    NaN
# 4      Antigua and Barbuda       NaN                                    NaN
# 5                Argentina     0.771                                    NaN
# 6                  Armenia     0.644                                   60.5
# 7                Australia     0.899                                    NaN
# 8                  Austria     0.837                                    NaN
# 9               Azerbaijan     0.642                                   55.1
# 10                 Bahamas     0.779                                    NaN
# ...

# %% [markdown]
# A pergunta que pretendo responder é a seguinte: Um alto índice percentual relativo ao uso de contraceptivos está relacionado com um IDH alto?
